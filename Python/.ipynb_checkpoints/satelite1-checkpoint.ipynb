# %%
import imageio.v2 as imageio
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt
# Out:
# C:\Users\denis\AppData\Local\Temp\ipykernel_56900\2074943770.py:3: DeprecationWarning: scipy.misc is deprecated and will be removed in 2.0.0
#   from scipy import misc

# %% [raw]
# Creiamo un numpy array da un'immagine

# %%
from skimage import data

photo_data = imageio.imread('./archive/sd-3layers.jpg')

type(photo_data)
# Out:
# C:\Users\denis\AppData\Local\Temp\ipykernel_56900\4190169938.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   photo_data = imageio.imread('./archive/sd-3layers.jpg')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from skimage import data
# ----> 3 photo_data = imageio.imread('./archive/sd-3layers.jpg')
#       5 type(photo_data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\__init__.py:100, in imread(uri, format, **kwargs)
#      71 """imread(uri, format=None, **kwargs)
#      72
#      73 Reads an image from the specified file. Returns a numpy array, which
#    (...)
#      89     to see what arguments are available for a particular format.
#      90 """
#      92 warnings.warn(
#      93     "Starting with ImageIO v3 the behavior of this function will switch to that of"
#      94     " iio.v3.imread. To keep the current behavior (and make this warning disappear)"
#    (...)
#      97     stacklevel=2,
#      98 )
# --> 100 return imread_v2(uri, format=format, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\v2.py:359, in imread(uri, format, **kwargs)
#     356 imopen_args = decypher_format_arg(format)
#     357 imopen_args["legacy_mode"] = True
# --> 359 with imopen(uri, "ri", **imopen_args) as file:
#     360     result = file.read(index=0, **kwargs)
#     362 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\core\imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\core\request.py:250, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     247     raise ValueError(f"Invalid Request.Mode: {mode}")
#     249 # Parse what was given
# --> 250 self._parse_uri(uri)
#     252 # Set extension
#     253 if extension is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\imageio\core\request.py:410, in Request._parse_uri(self, uri)
#     407 if is_read_request:
#     408     # Reading: check that the file exists (but is allowed a dir)
#     409     if not os.path.exists(fn):
# --> 410         raise FileNotFoundError("No such file: '%s'" % fn)
#     411 else:
#     412     # Writing: check that the directory to write to does exist
#     413     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: 'C:\Users\denis\source\repos\SuperD3ni\scuola\Python\archive\sd-3layers.jpg'

# %% [markdown]
# immagine

# %%
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %%
photo_data.shape

#print(photo_data)

# %% [markdown]
# La forma dell'ndarray mostra che è una matrice a tre strati. I primi due numeri  sono lunghezza e larghezza, e il terzo numero (cioè 3) è per tre strati: Rosso, Verde e Blu.

# %% [markdown]
# Il pixel ROSSO indica l'altitudine
#
# Il pixel BLU indica l'aspetto
#
# Il pixel VERDE indica la pendenza

# %%
photo_data.size

# %%
photo_data.min(), photo_data.max()

# %%
photo_data.mean()

# %% [markdown]
# Pixel alla 150-esima rigaw e 250-esima colonna

# %%
photo_data[150, 250]

# %%
photo_data[150, 250, 1]

# %% [markdown]
# Impostare un pixel su tutti gli zeri
#
#
# Possiamo impostare tutti e tre i livelli di un pixel  assegnando lo zero  a quell'accoppiamento (riga, colonna). Tuttavia, l'impostazione di un pixel a zero non si nota.

# %%
#photo_data = misc.imread('./wifire/sd-3layers.jpg')
photo_data[150, 250] = 0
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %% [markdown]
# Cambiare i colori in un intervallo
#
#
# Possiamo anche usare un intervallo per cambiare i valori dei pixel. Come esempio, impostiamo il livello del verde per le righe da 200 a 800 alla massima intensità.

# %%
photo_data = imageio.imread('./archive/sd-3layers.jpg')

photo_data[200:800, : ,0] = 255
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %%
photo_data = imageio.imread('./archive/sd-3layers.jpg')

photo_data[200:800, :] = 255
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %%
photo_data = imageio.imread('./archive/sd-3layers.jpg')

photo_data[200:800, :] = 0
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %% [markdown]
# <h1 style="color:red">Seleziona tutti i pixel con valori bassi</h1>

# %%
photo_data = imageio.imread('./archive/sd-3layers.jpg')
print("Shape of photo_data:", photo_data.shape)
low_value_filter = photo_data < 200
print("Shape of low_value_filter:", low_value_filter.shape)

# %% [markdown]
# <h1>Filtrare i valori bassi

# %%
#import random
plt.figure(figsize=(10,10))
plt.imshow(photo_data)
photo_data[low_value_filter] = 0
plt.figure(figsize=(10,10))
plt.imshow(photo_data)

# %% [markdown]
# Altre operazioni su righe e colonne
#
#
# Puoi progettare schemi complessi rendendo le colonne una funzione delle righe o viceversa. Qui proviamo una relazione lineare tra righe e colonne.

# %%
rows_range = np.arange(len(photo_data))
cols_range = rows_range
print(type(rows_range))

# %%
photo_data[rows_range, cols_range] = 255

# %%
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %% [markdown]
# Mascheramento delle immagini
#
#
# Ora proviamo qualcosa una maschera che ha la forma di un disco circolare.

# %%
total_rows, total_cols, total_layers = photo_data.shape
#print("photo_data = ", photo_data.shape)

X, Y = np.ogrid[:total_rows, :total_cols]
print("X = ", X.shape, " and Y = ", Y.shape)

# %%
center_row, center_col = total_rows / 2, total_cols / 2
#print("center_row = ", center_row, "AND center_col = ", center_col)
#print(X - center_row)
#print(Y - center_col)
dist_from_center = (X - center_row)**2 + (Y - center_col)**2
#print(dist_from_center)
radius = (total_rows / 2)**2
#print("Radius = ", radius)
circular_mask = (dist_from_center > radius)
#print(circular_mask)
print(circular_mask[1500:1700,2000:2200])

# %%
photo_data = imageio.imread('./archive/sd-3layers.jpg')
photo_data[circular_mask] = 0
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %% [markdown]
# Ulteriore mascheratura
#
#
# È possibile migliorare ulteriormente la maschera, per esempio ottenere solo la metà superiore del disco.

# %%
X, Y = np.ogrid[:total_rows, :total_cols]
half_upper = X < center_row # genera una maschera per tutte le righe sopra il centro

half_upper_mask = np.logical_and(half_upper, circular_mask)

# %%
photo_data = imageio.imread('./archive/sd-3layers.jpg')
photo_data[half_upper_mask] = 255
#photo_data[half_upper_mask] = random.randint(200,255)
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %% [markdown]
# Ulteriore elaborazione delle nostre immagini satellitari
#
# Elaborazione dei pixel rossi
#
# Ricordate che i pixel rossi ci dicono l'altezza. Cerchiamo di evidenziare tutte le aree ad alta quota. Lo faremo rilevando i pixel rossi ad alta intensità e smorzando le altre aree.

# %%
import imageio
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt
photo_data3 = imageio.imread('./archive/sd-3layers.jpg')
red_mask   = photo_data3[:, : ,0] < 150

photo_data3[red_mask] = 0
plt.figure(figsize=(15,15))
plt.imshow(photo_data3)

# %% [markdown]
# Rilevamento dei pixel verdi

# %%
photo_data = imageio.imread('./archive/sd-3layers.jpg')
green_mask = photo_data[:, : ,1] < 150

photo_data[green_mask] = 0
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %% [markdown]
# rilevamento pixel blue

# %%
import imageio
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt
photo_data = imageio.imread('./archive/sd-3layers.jpg')
blue_mask  = photo_data[:, : ,2] < 150

photo_data[blue_mask] = 0
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %% [markdown]
# Maschera  che prende le soglie su tutti e tre i livelli: ROSSO, VERDE, BLU

# %%
import imageio
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt
photo_data = imageio.imread('./archive/sd-3layers.jpg')
red_mask   = photo_data[:, : ,0] <250
green_mask = photo_data[:, : ,1] < 250
blue_mask  = photo_data[:, : ,2]<1

final_mask = np.logical_and(red_mask, green_mask, blue_mask)
photo_data[final_mask] = 0
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %%
import skimage.io
skimage.io.imsave(fname="clip.tif", arr=photo_data)
