# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
moon = plt.imread("5.1.09.tiff")
alarm = plt.imread("5.1.12.tiff")
mask = np.full((256, 256), False)

# %%
mask[65:180, 130:225] = True
plt.imshow(mask,cmap="gray")

# %%
fusion = moon.copy()
fusion[mask] = alarm[mask]

# %%
plt.imshow(fusion,cmap="gray")
