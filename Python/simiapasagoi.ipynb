# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
simia = plt.imread("4.2.03.tiff")
pae = plt.imread("4.2.06.tiff")

# %%
#rendo le immagini uguali in shape
if simia.shape != pae.shape:
    simia = simia[:pae.shape[0], :pae.shape[1]]
